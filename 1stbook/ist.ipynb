# %%
PANDAS
1.Pandas is a Python library used for working with data sets.
2.It has the functions for analyzing, cleaning, exploring and manipulating data.

# %% [markdown]
# pandas installation

# %%
pip install pandas

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Importing pandas

# %%
import pandas as pd

# %% [markdown]
# pandas version

# %%
print(pd.__version__)
# Out:
# 2.2.3

# %% [markdown]
# Installing Specific version
# #pip install pandas= 1.4.2

# %% [markdown]
# Types of pandas data structures are :
# 1.Series 2.Data Frames 3.Panel
# Series : one D array with any data type.

# %%
#creating a series with default integer index
s=pd.Series([10,20,30,40,50])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
#Creating a Series with custom index labels
S1 = pd.Series([10,20,30,40], index=['a','b','c','d'])
print(S1)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
S1['c']
# Out:
# np.int64(30)

# %%
s[2]
# Out:
# np.int64(30)

# %%
# using list 
ls=[10,20,30,40]
pd.Series(ls)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
pd.Series(ls,index =["i","ii","iii","iv"])
# Out:
# i      10
# ii     20
# iii    30
# iv     40
# dtype: int64

# %% [markdown]
# Data Frames
# pandas dataframes is a 2 dimensional data structure
# similar to 2 dimensional array
# Table with rows and columns

# %%
# Creating a Dataframe
mydataset={"cars":['bmw','volvo','ford'],'passing' :[3,7,2]}
myvar=pd.DataFrame(mydataset)

# %%
myvar
# Out:
#     cars  passing
# 0    bmw        3
# 1  volvo        7
# 2   ford        2

# %%
print(myvar.cars[0])
# Out:
# bmw

# %%
# creating another data frame 
data = {"Name" :['soujanya','Santhosh','Hithesh'],
        "Age":[34,30,25],
        "City":['Delhi','Hyderabad','Kerala']
        }
df=pd.DataFrame(data)

# %%
df
# Out:
#        Name  Age       City
# 0  soujanya   34      Delhi
# 1  Santhosh   30  Hyderabad
# 2   Hithesh   25     Kerala

# %%
#Filtering data
print(df[df['Age']>25])
# Out:
#        Name  Age       City
# 0  soujanya   34      Delhi
# 1  Santhosh   30  Hyderabad

# %%
#Adding a new column
df['salary'] = [50000,80000,40000]

# %%
df
# Out:
#        Name  Age       City  salary
# 0  soujanya   34      Delhi   50000
# 1  Santhosh   30  Hyderabad   80000
# 2   Hithesh   25     Kerala   40000

# %%
#summary
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
#  3   salary  3 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 224.0+ bytes
# None

# %%
#Adding a new column with some Operations
import pandas as pd
dic={'items':['pen','pencil','book','A4 paper','toy','fan','light'],
     'cost':[10,20,50,60,30,2000,500],
     'quantity':[10,34,20,15,16,5,1]
     }
df2=pd.DataFrame(dic)
df2
# Out:
#       items  cost  quantity
# 0       pen    10        10
# 1    pencil    20        34
# 2      book    50        20
# 3  A4 paper    60        15
# 4       toy    30        16
# 5       fan  2000         5
# 6     light   500         1

# %%
#df2['Totalprice']=df2['cost']*df2['quantity']
df2['cost']*df2['quantity']
# Out:
# 0      100
# 1      680
# 2     1000
# 3      900
# 4      480
# 5    10000
# 6      500
# dtype: int64

# %%
df2
# Out:
#       items  cost  quantity
# 0       pen    10        10
# 1    pencil    20        34
# 2      book    50        20
# 3  A4 paper    60        15
# 4       toy    30        16
# 5       fan  2000         5
# 6     light   500         1

# %%
df2['Totalprice']=df2['cost']*df2['quantity']
df2
# Out:
#       items  cost  quantity  Totalprice
# 0       pen    10        10         100
# 1    pencil    20        34         680
# 2      book    50        20        1000
# 3  A4 paper    60        15         900
# 4       toy    30        16         480
# 5       fan  2000         5       10000
# 6     light   500         1         500

# %%
# Selecting and Slicing
#iloc and loc
df2
# Out:
#       items  cost  quantity  Totalprice
# 0       pen    10        10         100
# 1    pencil    20        34         680
# 2      book    50        20        1000
# 3  A4 paper    60        15         900
# 4       toy    30        16         480
# 5       fan  2000         5       10000
# 6     light   500         1         500

# %%
df2.iloc[2]
# Out:
# items         book
# cost            50
# quantity        20
# Totalprice    1000
# Name: 2, dtype: object

# %%
df2.iloc[[2,3,4]]
# Out:
#       items  cost  quantity  Totalprice
# 2      book    50        20        1000
# 3  A4 paper    60        15         900
# 4       toy    30        16         480

# %%
df2.loc[[1,4],['items','Totalprice']]
# Out:
#     items  Totalprice
# 1  pencil         680
# 4     toy         480

# %%
df2.loc[[1,4],['cost','Totalprice']]
# Out:
#    cost  Totalprice
# 1    20         680
# 4    30         480

# %%
df2.loc[4,'items']
# Out:
# 'toy'

# %%
# Analysis
df3=df2.copy()
df3
# Out:
#       items  cost  quantity  Totalprice
# 0       pen    10        10         100
# 1    pencil    20        34         680
# 2      book    50        20        1000
# 3  A4 paper    60        15         900
# 4       toy    30        16         480
# 5       fan  2000         5       10000
# 6     light   500         1         500

# %%
df2
# Out:
#       items  cost  quantity  Totalprice
# 0       pen    10        10         100
# 1    pencil    20        34         680
# 2      book    50        20        1000
# 3  A4 paper    60        15         900
# 4       toy    30        16         480
# 5       fan  2000         5       10000
# 6     light   500         1         500

# %%
df3.columns
# Out:
# Index(['items', 'cost', 'quantity', 'Totalprice'], dtype='object')

# %%
df3.head()
# Out:
#       items  cost  quantity  Totalprice
# 0       pen    10        10         100
# 1    pencil    20        34         680
# 2      book    50        20        1000
# 3  A4 paper    60        15         900
# 4       toy    30        16         480

# %%
df3.tail()
# Out:
#       items  cost  quantity  Totalprice
# 2      book    50        20        1000
# 3  A4 paper    60        15         900
# 4       toy    30        16         480
# 5       fan  2000         5       10000
# 6     light   500         1         500

# %%
df3.tail(1)
# Out:
#    items  cost  quantity  Totalprice
# 6  light   500         1         500

# %%
df3.head(1)
# Out:
#   items  cost  quantity  Totalprice
# 0   pen    10        10         100

# %%
df3.head(2)
# Out:
#     items  cost  quantity  Totalprice
# 0     pen    10        10         100
# 1  pencil    20        34         680

# %%
#changing values

# %%
df3
# Out:
#       items  cost  quantity  Totalprice
# 0       pen    10        10         100
# 1    pencil    20        34         680
# 2      book    50        20        1000
# 3  A4 paper    60        15         900
# 4       toy    30        16         480
# 5       fan  2000         5       10000
# 6     light   500         1         500

# %%
df3.iloc[2,2]=50

# %%
df3.iloc[2,3]
# Out:
# np.float64(1000.0)

# %%
import numpy as np

# %%
#df3.iloc[5,3]=np.nan

# %%
df3
# Out:
#       items  cost  quantity  Totalprice
# 0       pen    10        10       100.0
# 1    pencil    20        34       680.0
# 2      book    50        50      1000.0
# 3  A4 paper    60        15       900.0
# 4       toy    30        16       480.0
# 5       fan  2000         5         NaN
# 6     light   500         1       500.0

# %%
df3.iloc[3,1]
# Out:
# np.int64(60)

# %%
df3.iloc[3,1]=np.nan

# %%
df3
# Out:
#       items    cost  quantity  Totalprice
# 0       pen    10.0        10       100.0
# 1    pencil    20.0        34       680.0
# 2      book    50.0        50      1000.0
# 3  A4 paper     NaN        15       900.0
# 4       toy    30.0        16       480.0
# 5       fan  2000.0         5         NaN
# 6     light   500.0         1       500.0

# %%
df3.iloc[6,2]='10'
# Out:
# /tmp/ipykernel_5229/3746136714.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df3.iloc[6,2]='10'

# %%
df3
# Out:
#       items    cost quantity  Totalprice
# 0       pen    10.0       10       100.0
# 1    pencil    20.0       34       680.0
# 2      book    50.0       50      1000.0
# 3  A4 paper     NaN       15       900.0
# 4       toy    30.0       16       480.0
# 5       fan  2000.0        5         NaN
# 6     light   500.0       10       500.0

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   items       7 non-null      object
#  1   cost        6 non-null      float64
#  2   quantity    7 non-null      object
#  3   Totalprice  6 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 352.0+ bytes

# %%
# Cleaning
#  1. wrong data
#  2. empty cells (remove and replace)
#  3.duplicates
#  4.wrong format

# %%
df2
# Out:
#       items  cost  quantity  Totalprice
# 0       pen    10        10         100
# 1    pencil    20        34         680
# 2      book    50        20        1000
# 3  A4 paper    60        15         900
# 4       toy    30        16         480
# 5       fan  2000         5       10000
# 6     light   500         1         500

# %%
df3
# Out:
#       items    cost quantity  Totalprice
# 0       pen    10.0       10       100.0
# 1    pencil    20.0       34       680.0
# 2      book    50.0       50      1000.0
# 3  A4 paper     NaN       15       900.0
# 4       toy    30.0       16       480.0
# 5       fan  2000.0        5         NaN
# 6     light   500.0       10       500.0

# %%
df3.dropna()
# Out:
#     items   cost quantity  Totalprice
# 0     pen   10.0       10       100.0
# 1  pencil   20.0       34       680.0
# 2    book   50.0       50      1000.0
# 4     toy   30.0       16       480.0
# 6   light  500.0       10       500.0

# %%
df3
# Out:
#       items    cost quantity  Totalprice
# 0       pen    10.0       10       100.0
# 1    pencil    20.0       34       680.0
# 2      book    50.0       50      1000.0
# 3  A4 paper     NaN       15       900.0
# 4       toy    30.0       16       480.0
# 5       fan  2000.0        5         NaN
# 6     light   500.0       10       500.0

# %%
df4=df3.dropna() #original will not change

# %%
df4
# Out:
#     items   cost quantity  Totalprice
# 0     pen   10.0       10       100.0
# 1  pencil   20.0       34       680.0
# 2    book   50.0       50      1000.0
# 4     toy   30.0       16       480.0
# 6   light  500.0       10       500.0

# %%
df3
# Out:
#       items    cost quantity  Totalprice
# 0       pen    10.0       10       100.0
# 1    pencil    20.0       34       680.0
# 2      book    50.0       50      1000.0
# 3  A4 paper     NaN       15       900.0
# 4       toy    30.0       16       480.0
# 5       fan  2000.0        5         NaN
# 6     light   500.0       10       500.0

# %%
df3.dropna(inplace=True)  #original will change

# %%
df3
# Out:
#     items   cost quantity  Totalprice
# 0     pen   10.0       10       100.0
# 1  pencil   20.0       34       680.0
# 2    book   50.0       50      1000.0
# 4     toy   30.0       16       480.0
# 6   light  500.0       10       500.0

# %%
df2
# Out:
#       items  cost  quantity  Totalprice
# 0       pen    10        10         100
# 1    pencil    20        34         680
# 2      book    50        20        1000
# 3  A4 paper    60        15         900
# 4       toy    30        16         480
# 5       fan  2000         5       10000
# 6     light   500         1         500

# %%
temp= pd.concat([df3,df2])

# %%
temp
# Out:
#       items    cost quantity  Totalprice
# 0       pen    10.0       10       100.0
# 1    pencil    20.0       34       680.0
# 2      book    50.0       50      1000.0
# 4       toy    30.0       16       480.0
# 6     light   500.0       10       500.0
# 0       pen    10.0       10       100.0
# 1    pencil    20.0       34       680.0
# 2      book    50.0       20      1000.0
# 3  A4 paper    60.0       15       900.0
# 4       toy    30.0       16       480.0
# 5       fan  2000.0        5     10000.0
# 6     light   500.0        1       500.0

# %%
temp.reset_index()
# Out:
#     index     items    cost quantity  Totalprice
# 0       0       pen    10.0       10       100.0
# 1       1    pencil    20.0       34       680.0
# 2       2      book    50.0       50      1000.0
# 3       4       toy    30.0       16       480.0
# 4       6     light   500.0       10       500.0
# 5       0       pen    10.0       10       100.0
# 6       1    pencil    20.0       34       680.0
# 7       2      book    50.0       20      1000.0
# 8       3  A4 paper    60.0       15       900.0
# 9       4       toy    30.0       16       480.0
# 10      5       fan  2000.0        5     10000.0
# 11      6     light   500.0        1       500.0

# %%
temp.reset_index(drop=True)
# Out:
#        items    cost quantity  Totalprice
# 0        pen    10.0       10       100.0
# 1     pencil    20.0       34       680.0
# 2       book    50.0       50      1000.0
# 3        toy    30.0       16       480.0
# 4      light   500.0       10       500.0
# 5        pen    10.0       10       100.0
# 6     pencil    20.0       34       680.0
# 7       book    50.0       20      1000.0
# 8   A4 paper    60.0       15       900.0
# 9        toy    30.0       16       480.0
# 10       fan  2000.0        5     10000.0
# 11     light   500.0        1       500.0

# %%
temp
# Out:
#       items    cost quantity  Totalprice
# 0       pen    10.0       10       100.0
# 1    pencil    20.0       34       680.0
# 2      book    50.0       50      1000.0
# 4       toy    30.0       16       480.0
# 6     light   500.0       10       500.0
# 0       pen    10.0       10       100.0
# 1    pencil    20.0       34       680.0
# 2      book    50.0       20      1000.0
# 3  A4 paper    60.0       15       900.0
# 4       toy    30.0       16       480.0
# 5       fan  2000.0        5     10000.0
# 6     light   500.0        1       500.0

# %%
df2
# Out:
#       items  cost  quantity  Totalprice
# 0       pen    10        10         100
# 1    pencil    20        34         680
# 2      book    50        20        1000
# 3  A4 paper    60        15         900
# 4       toy    30        16         480
# 5       fan  2000         5       10000
# 6     light   500         1         500

# %%
df2.iloc[3,1]=np.nan

# %%
df2
# Out:
#       items    cost  quantity  Totalprice
# 0       pen    10.0        10         100
# 1    pencil    20.0        34         680
# 2      book    50.0        20        1000
# 3  A4 paper     NaN        15         900
# 4       toy    30.0        16         480
# 5       fan  2000.0         5       10000
# 6     light   500.0         1         500

# %%
#wrong data
df2.fillna('hi')
# Out:
#       items    cost  quantity  Totalprice
# 0       pen    10.0        10         100
# 1    pencil    20.0        34         680
# 2      book    50.0        20        1000
# 3  A4 paper      hi        15         900
# 4       toy    30.0        16         480
# 5       fan  2000.0         5       10000
# 6     light   500.0         1         500

# %%
df2
# Out:
#       items  cost  quantity
# 0       pen    10        10
# 1    pencil    20        34
# 2      book    50        20
# 3  A4 paper    60        15
# 4       toy    30        16
# 5       fan  2000         5
# 6     light   500         1

# %%
df2.shape
# Out:
# (7, 3)
